# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Mohan Kumar A** <br>
# Data Scientist

# %% [markdown]
# *I am interested in data science because I want to help people in taking their business to a next level by using the valuable insights of data*

# %% [markdown]
# ### The following code returns the square of an interger

# %%
def squareNum(n):
    return n*n


squareNum(3)
# Out:
# 9

# %% [markdown]
# **1. Blocked Quote**
# > Blocked Quote
#
# **2. Horizontal Rule**
# ***
#
# Horizontal Rule
#
# ***
#
# **3. Bulleted List**
# * This is a bullet list
# * This is a bullet list
# * This is a bullet list
#
# **4. Table**
#
# | Male/Female | Age |
# | --- | --- |
# | Male | 23 |
# | Female | 25 |
# | Male | 12 |
#
#
# **5. StrikeThrough**
#
# <strike>StrikeThrough<strike>
